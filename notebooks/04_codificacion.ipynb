# %%
import pandas as pd

# %% [markdown]
# # ONE-HOT-ENCODING: para variables categoricas nominales (bien)
# # ONE-HOT-ENCODING: para variables categoricas ordinales (bien, pero se pierde la "jerarquia" u "orden")
#
# # LABEL ENCODING: para variables categoricas ordinales (bien), el unico problema es definir los "valores" de las clases.
# # LABEL ENCODING:: para variables categoricas nominales (pesimo), se va a sesgar y un modelo podria interpretar una jerarquia/orden donde no existe.

# %%
PATH_PROJECT = 'C:/Users/vatec/OneDrive/Documentos/Hans/Cursos/5 CODERHOUSE - Data Science II - Machine Learning para la Ciencia de Datos Flex/Material/Proyectos/Template Model Project DS/'


PATH = PATH_PROJECT +'data/processed/'

# %%
df = pd.read_csv(f'{PATH}dataset_merged_processed_eda.csv')

# %%
df_copy = df.copy()
df_copy_2 = df.copy()

# %% [markdown]
# Opcion 1)

# %%
df
# Out:
#           ID  systolic  relaxation  Cholesterol  triglyceride       HDL  \
# 0          0  4.750000    3.041667     8.958333      3.416667  3.041667
# 1          1  4.958333    2.916667     8.000000      4.791667  1.750000
# 2          2  5.750000    3.583333    10.083333      7.583333  2.291667
# 3          3  4.166667    2.500000    13.416667     10.583333  1.875000
# 4          4  5.000000    3.083333     7.666667      3.083333  2.583333
# ...      ...       ...         ...          ...           ...       ...
# 49995  27343  5.062688    3.167519     8.206039      5.275309  2.625000
# 49996  27350  5.062688    3.167519     8.206039      5.275309  2.250000
# 49997  27351  5.062688    3.167519     8.206039      5.275309  1.958333
# 49998  27352  5.062688    3.167519     8.206039      5.275309  2.583333
# 49999  27354  5.062688    3.167519     8.206039      5.275309  2.750000
#
#             LDL gender   age  height(cm)  ...  tartar  eyesight(left)_x  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50000 non-null  int64
#  1   systolic             50000 non-null  float64
#  2   relaxation           50000 non-null  float64
#  3   Cholesterol          50000 non-null  float64
#  4   triglyceride         50000 non-null  float64
#  5   HDL                  50000 non-null  float64
#  6   LDL                  50000 non-null  float64
#  7   gender               50000 non-null  str
#  8   age                  50000 non-null  float64
#  9   height(cm)           50000 non-null  float64
#  10  weight(kg)           50000 non-null  float64
#  11  waist(cm)            50000 non-null  float64
#  12  fasting blood sugar  50000 non-null  float64
#  13  hemoglobin           50000 non-null  float64
#  14  Urine protein        50000 non-null  float64
# ...

# %%
df.gender.nunique()
# Out:
# 2

# %%
df.tartar.unique()
# Out:
# <StringArray>
# ['Y', 'N']
# Length: 2, dtype: str

# %%
df["gender"] = df["gender"].map({"F": 0, "M": 1})

# %%
df["tartar"] = df["tartar"].map({"N": 0, "Y": 1})

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50000 non-null  int64
#  1   systolic             50000 non-null  float64
#  2   relaxation           50000 non-null  float64
#  3   Cholesterol          50000 non-null  float64
#  4   triglyceride         50000 non-null  float64
#  5   HDL                  50000 non-null  float64
#  6   LDL                  50000 non-null  float64
#  7   gender               50000 non-null  int64
#  8   age                  50000 non-null  float64
#  9   height(cm)           50000 non-null  float64
#  10  weight(kg)           50000 non-null  float64
#  11  waist(cm)            50000 non-null  float64
#  12  fasting blood sugar  50000 non-null  float64
#  13  hemoglobin           50000 non-null  float64
#  14  Urine protein        50000 non-null  float64
# ...

# %% [markdown]
# Opcion 2)

# %%
df_op_2 = pd.get_dummies(df_copy, columns=["gender", "tartar"], drop_first=True)

# %%
df_op_2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50000 non-null  int64
#  1   systolic             50000 non-null  float64
#  2   relaxation           50000 non-null  float64
#  3   Cholesterol          50000 non-null  float64
#  4   triglyceride         50000 non-null  float64
#  5   HDL                  50000 non-null  float64
#  6   LDL                  50000 non-null  float64
#  7   age                  50000 non-null  float64
#  8   height(cm)           50000 non-null  float64
#  9   weight(kg)           50000 non-null  float64
#  10  waist(cm)            50000 non-null  float64
#  11  fasting blood sugar  50000 non-null  float64
#  12  hemoglobin           50000 non-null  float64
#  13  Urine protein        50000 non-null  float64
#  14  serum creatinine     50000 non-null  float64
# ...

# %%
# df_op_2["gender_F"] = df_op_2["gender_F"].astype(int)
df_op_2["gender_M"] = df_op_2["gender_M"].astype(int)
# df_op_2["tartar_N"] = df_op_2["tartar_N"].astype(int)
df_op_2["tartar_Y"] = df_op_2["tartar_Y"].astype(int)

# %%
df_op_2
# Out:
#           ID  systolic  relaxation  Cholesterol  triglyceride       HDL  \
# 0          0  4.750000    3.041667     8.958333      3.416667  3.041667
# 1          1  4.958333    2.916667     8.000000      4.791667  1.750000
# 2          2  5.750000    3.583333    10.083333      7.583333  2.291667
# 3          3  4.166667    2.500000    13.416667     10.583333  1.875000
# 4          4  5.000000    3.083333     7.666667      3.083333  2.583333
# ...      ...       ...         ...          ...           ...       ...
# 49995  27343  5.062688    3.167519     8.206039      5.275309  2.625000
# 49996  27350  5.062688    3.167519     8.206039      5.275309  2.250000
# 49997  27351  5.062688    3.167519     8.206039      5.275309  1.958333
# 49998  27352  5.062688    3.167519     8.206039      5.275309  2.583333
# 49999  27354  5.062688    3.167519     8.206039      5.275309  2.750000
#
#             LDL   age  height(cm)  weight(kg)  ...  eyesight(right)_x  \
# ...

# %%
df_op_2.to_csv(PATH + "dataset_merged_processed_cod.csv", index=False)

# %% [markdown]
# Opcion 3) "Teorica"

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder(handle_unknown = "Ignore") # si el dia de mañana, las variables categoricas pueden o van a tener valores nuevos desconocidos al momento de entrenar, usar "handle_unknown=.."

# %%
# para entrenar el ohe, debemos usar X_train (SIEMPRE CON .FIT() DEBEN USAR EL CONJUNTO DE ENTRENAMIENTO")

# %%
help(OneHotEncoder)
# Out:
# Help on class OneHotEncoder in module sklearn.preprocessing._encoders:
#
# class OneHotEncoder(_BaseEncoder)
#  |  OneHotEncoder(
#  |      *,
#  |      categories='auto',
#  |      drop=None,
#  |      sparse_output=True,
#  |      dtype=<class 'numpy.float64'>,
#  |      handle_unknown='error',
#  |      min_frequency=None,
#  |      max_categories=None,
#  |      feature_name_combiner='concat'
#  |  )
#  |
#  |  Encode categorical features as a one-hot numeric array.
#  |
#  |  The input to this transformer should be an array-like of integers or
#  |  strings, denoting the values taken on by categorical (discrete) features.
#  |  The features are encoded using a one-hot (aka 'one-of-K' or 'dummy')
#  |  encoding scheme. This creates a binary column for each category and
#  |  returns a sparse matrix or dense array (depending on the ``sparse_output``
#  |  parameter).
#  |
#  |  By default, the encoder derives the categories based on the unique values
# ...
