# %% [markdown]
# #### Librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Parametros

# %%
PATH_PROJECT = 'C:/Users/vatec/OneDrive/Documentos/Hans/Cursos/5 CODERHOUSE - Data Science II - Machine Learning para la Ciencia de Datos Flex/Material/Proyectos/Template Model Project DS/'

PATH = PATH_PROJECT +'data/processed/'

# %% [markdown]
# #### Lectura del archivo

# %%
df = pd.read_csv(f'{PATH}dataset_merged.csv')

# %%
df.head(3)
# Out:
#    ID  systolic  relaxation  Cholesterol  triglyceride       HDL       LDL  \
# 0   0  4.750000    3.041667     8.958333      3.416667  3.041667  5.250000
# 1   1  4.958333    2.916667     8.000000      4.791667  1.750000  5.291667
# 2   2  5.750000    3.583333    10.083333      7.583333  2.291667  6.291667
#
#   gender   age  height(cm)  ...  tartar  eyesight(left)_x  eyesight(right)_x  \
# 0      F  40.0       155.0  ...       Y          0.043056           0.041667
# 1      F  40.0       160.0  ...       Y          0.005556           0.004167
# 2      M  55.0       170.0  ...       N          0.005556           0.005556
#
#    hearing(left)_x  hearing(right)_x  eyesight(left)_y  eyesight(right)_y  \
# 0         0.041667          0.041667          0.043056           0.041667
# 1         0.041667          0.041667          0.005556           0.004167
# 2         0.041667          0.041667          0.005556           0.005556
#
#    hearing(left)_y  hearing(right)_y target
# ...

# %%
df.tail(3)
# Out:
#           ID  systolic  relaxation  Cholesterol  triglyceride       HDL  \
# 49997  27351       NaN         NaN          NaN           NaN  1.958333
# 49998  27352       NaN         NaN          NaN           NaN  2.583333
# 49999  27354       NaN         NaN          NaN           NaN  2.750000
#
#             LDL gender   age  height(cm)  ...  tartar  eyesight(left)_x  \
# 49997  2.208333      M  20.0       165.0  ...       Y          0.045139
# 49998  4.125000      F  60.0       160.0  ...       Y          0.002778
# 49999  5.041667      M  45.0       170.0  ...       N          0.045139
#
#        eyesight(right)_x  hearing(left)_x  hearing(right)_x  eyesight(left)_y  \
# 49997           0.045139         0.041667               NaN          0.045139
# 49998           0.002778         0.041667               NaN          0.002778
# 49999           0.041667         0.041667               NaN          0.045139
#
#        eyesight(right)_y  hearing(left)_y  hearing(right)_y target
# ...

# %%
df.sample(5, random_state=42)
# Out:
#           ID  systolic  relaxation  Cholesterol  triglyceride       HDL  \
# 33553  41917  6.000000    3.958333        8.375      1.875000  2.500000
# 9427   11817  5.208333    3.125000        8.125      2.916667  3.291667
# 199      260       NaN         NaN          NaN      4.250000  2.333333
# 12447  15517  5.791667    3.416667       10.625      5.750000  2.750000
# 39489  49334  4.375000    2.708333        7.375      4.375000  2.583333
#
#             LDL gender   age  height(cm)  ...  tartar  eyesight(left)_x  \
# 33553  5.500000      M  55.0       175.0  ...       N          0.041667
# 9427   4.250000      F  40.0       160.0  ...       Y          0.006250
# 199    5.458333      F  40.0       150.0  ...       N          0.005556
# 12447  6.708333      F  50.0       155.0  ...       N          0.043056
# 39489  3.916667      F  45.0       150.0  ...       Y          0.041667
#
#        eyesight(right)_x  hearing(left)_x  hearing(right)_x  eyesight(left)_y  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50000 non-null  int64
#  1   systolic             49592 non-null  float64
#  2   relaxation           49588 non-null  float64
#  3   Cholesterol          49390 non-null  float64
#  4   triglyceride         49979 non-null  float64
#  5   HDL                  49053 non-null  float64
#  6   LDL                  49053 non-null  float64
#  7   gender               49963 non-null  str
#  8   age                  49523 non-null  float64
#  9   height(cm)           49587 non-null  float64
#  10  weight(kg)           49914 non-null  float64
#  11  waist(cm)            49616 non-null  float64
#  12  fasting blood sugar  49142 non-null  float64
#  13  hemoglobin           49859 non-null  float64
#  14  Urine protein        49841 non-null  float64
# ...

# %%
df.isna().sum()/df.shape[0]*100 # porcentaje de valores nulos por columna
# Out:
# ID                      0.000
# systolic                0.816
# relaxation              0.824
# Cholesterol             1.220
# triglyceride            0.042
# HDL                     1.894
# LDL                     1.894
# gender                  0.074
# age                     0.954
# height(cm)              0.826
# weight(kg)              0.172
# waist(cm)               0.768
# fasting blood sugar     1.716
# hemoglobin              0.282
# Urine protein           0.318
# serum creatinine       22.118
# AST                    91.504
# ALT                     0.644
# Gtp                     0.126
# oral                    0.000
# dental caries           0.000
# tartar                  0.000
# eyesight(left)_x        1.404
# eyesight(right)_x       0.952
# hearing(left)_x         0.224
# hearing(right)_x        0.442
# eyesight(left)_y        1.404
# eyesight(right)_y       0.952
# hearing(left)_y         0.224
# hearing(right)_y        0.442
# target                  0.000
# ...

# %%
df.shape
# Out:
# (50000, 31)

# %%
df = df.drop(columns=["AST"])

# %%
df = df.fillna(df.mean(numeric_only=True))

# %%
df.gender.unique()
# Out:
# <StringArray>
# ['F', 'M', nan]
# Length: 3, dtype: str

# %%
random_gender = np.random.choice(["F","M"], size=df["gender"].isnull().sum())

# %%
random_gender
# Out:
# array(['F', 'F', 'M', 'F', 'M', 'M', 'F', 'M', 'M', 'F', 'F', 'F', 'M',
#        'M', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F',
#        'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'F'], dtype='<U1')

# %%
df.loc[df["gender"].isnull(),"gender"] = random_gender

# %%
df.isna().sum()/df.shape[0]*100 # porcentaje de valores nulos por columna
# Out:
# ID                     0.0
# systolic               0.0
# relaxation             0.0
# Cholesterol            0.0
# triglyceride           0.0
# HDL                    0.0
# LDL                    0.0
# gender                 0.0
# age                    0.0
# height(cm)             0.0
# weight(kg)             0.0
# waist(cm)              0.0
# fasting blood sugar    0.0
# hemoglobin             0.0
# Urine protein          0.0
# serum creatinine       0.0
# ALT                    0.0
# Gtp                    0.0
# oral                   0.0
# dental caries          0.0
# tartar                 0.0
# eyesight(left)_x       0.0
# eyesight(right)_x      0.0
# hearing(left)_x        0.0
# hearing(right)_x       0.0
# eyesight(left)_y       0.0
# eyesight(right)_y      0.0
# hearing(left)_y        0.0
# hearing(right)_y       0.0
# target                 0.0
# dtype: float64

# %%
df.head(5)
# Out:
#    ID  systolic  relaxation  Cholesterol  triglyceride       HDL       LDL  \
# 0   0  4.750000    3.041667     8.958333      3.416667  3.041667  5.250000
# 1   1  4.958333    2.916667     8.000000      4.791667  1.750000  5.291667
# 2   2  5.750000    3.583333    10.083333      7.583333  2.291667  6.291667
# 3   3  4.166667    2.500000    13.416667     10.583333  1.875000  9.416667
# 4   4  5.000000    3.083333     7.666667      3.083333  2.583333  4.458333
#
#   gender   age  height(cm)  ...  tartar  eyesight(left)_x  eyesight(right)_x  \
# 0      F  40.0       155.0  ...       Y          0.043056           0.041667
# 1      F  40.0       160.0  ...       Y          0.005556           0.004167
# 2      M  55.0       170.0  ...       N          0.005556           0.005556
# 3      M  40.0       165.0  ...       Y          0.045139           0.045139
# 4      F  40.0       155.0  ...       N          0.041667           0.041667
#
# ...

# %%
df.ID.nunique()
# Out:
# 50000

# %%
df.duplicated().sum() # sacar el ID
# Out:
# np.int64(0)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50000, step=1)

# %%
df.columns
# Out:
# Index(['ID', 'systolic', 'relaxation', 'Cholesterol', 'triglyceride', 'HDL',
#        'LDL', 'gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)',
#        'fasting blood sugar', 'hemoglobin', 'Urine protein',
#        'serum creatinine', 'ALT', 'Gtp', 'oral', 'dental caries', 'tartar',
#        'eyesight(left)_x', 'eyesight(right)_x', 'hearing(left)_x',
#        'hearing(right)_x', 'eyesight(left)_y', 'eyesight(right)_y',
#        'hearing(left)_y', 'hearing(right)_y', 'target'],
#       dtype='str')

# %%
df.describe()
# Out:
#                  ID      systolic    relaxation   Cholesterol  triglyceride  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean   26284.994580      5.062688      3.167519      8.206039      5.275309
# std    16015.070567      0.567825      0.401889      1.506033      2.980229
# min        0.000000      2.958333      1.666667      2.291667      0.333333
# 25%    12499.750000      4.666667      2.916667      7.166667      3.083333
# 50%    24999.500000      5.000000      3.166667      8.166667      4.500000
# 75%    40034.250000      5.416667      3.416667      9.125000      6.666667
# max    55690.000000     10.000000      6.083333     18.541667     41.625000
#
#                 HDL           LDL           age    height(cm)    weight(kg)  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       2.387391      4.791840     44.188155    164.646278     65.877008
# ...

# %%
df.oral.unique()
# Out:
# <StringArray>
# ['Y']
# Length: 1, dtype: str

# %%
df.tartar.unique()
# Out:
# <StringArray>
# ['Y', 'N']
# Length: 2, dtype: str

# %%
df = df.drop(columns=["oral"]) # tiene 1 solo valor

# %%
df.to_csv(PATH_PROJECT + "data/processed/dataset_merged_processed.csv", index=False)
